# %% [markdown]
# # Lab Assignment 4: Using APIs in Python
# ## DS 6001: Practice and Application of Data Science
#
# ### Instructions
# Please answer the following questions as completely as possible using text, code, and the results of code as needed. Format your answers in a Jupyter notebook. To receive full credit, make sure you address every part of the problem, and make sure your document is formatted in a clean and professional way.

# %% [markdown]
# In this lab, you will work with the public API provided by [genius.com](https://genius.com/), a website that calls itself "the world’s biggest collection of song lyrics and musical knowledge." You will need to read the API documentation carefully, acquire an access key, and use it without sharing it to pull data from this API into Python. You will also practice using a library made specifically to wrap around `requests` to make calling from the Genius API easier.
#
# ## Problem 0
# Import the following libraries:

# %%
import numpy as np
import pandas as pd
import requests
import json
import os
import dotenv
import sys
sys.tracebacklimit = 0 # turn off the error tracebacks

# %% [markdown]
# ## Problem 1
# The Genius API documentation is here: https://docs.genius.com/#/getting-started-h1. Read through the documentation carefully. Although the Genius API is free and public, it still requires users an access key to use the API. In this case, Genius provides users with three codes: a client ID, a client ID secret, and a client access token. Use the documentation to find a way to obtain these codes for yourself. Write a paragraph that describes all of the steps you needed to take (but DO NOT list your access codes in this paragraph).
#
# Some hints and cautions:
#
# 1. Before you can use the API, you will need a regular, free user account with Genius. Sign-up here: https://genius.com/signup_or_login
#
# 2. Genius's API is built to support third-party app development, not data scientists. The language is entirely geared toward app development. Under "Authentication" there are instructions to third-party developers for guiding their own users in getting access keys. That's not relevant to getting access for yourself. It's not hard to get an access key, but the guidance here is not very clear. Be patient and read everything in the Authentication section carefully.
#
# 3. When you arrive at the page that allows you to register for API access keys, the language is still geared toward app development. You will be prompted to name your app and provide the URLs associated with the app. It doesn't much matter what you name your app, and I just used the Collab main page (https://collab.its.virginia.edu/portal?containerLogin=true) for the URLs.
#
# 4. When you get your codes, copy them in a text file. In problem 2 you will copy these codes over again to a `.env` file. [4 points]

# %% [markdown]
# ## Problem 2
# Create a `.env` file for this project. Open it, copy your access codes into it, and save it. Then use Python code to load the environmental variables contained in the `.env` file, and create variables that contain each of the three codes. (You can print these variables to make sure it worked, but do not allow your access keys to display in your notebook). [4 points]

# %%
import os
import dotenv
dotenv.load_dotenv()

# a client ID, a client ID secret, and a client access token.
# app name = wow
#app_website_url = os.getenv('APPWEBSITEURL')
#redirect_url = os.getenv('REDIRECTURI')
client_id = os.getenv('CLIENTID')
client_secret = os.getenv('CLIENTSECRET')
access_token = os.getenv('ClientACCESSTOKEN')

# %% [markdown]
# ## Problem 3
# The root for all Genius APIs is https://api.genius.com. Find the endpoint for the Search API. (You will have to click the "Authorize with Genius" button in the upper-right corner if you haven't already done so). Use the `requests` library to issue a search for Bob Dylan. Genius's API is organized in a way that every individual artist has his or her own API endpoint. Display a portion of the JSON output that displays the API endpoint path for the data on Bob Dylan.
#
# Hint: to authenticate, specify your access token (not your client ID or client secret) as the `access_token` parameter. You will have to dig around the JSON output to find the artist ID, but it is listed under `primary_artist` several branches down the JSON tree. [4 points]

# %%
p_dict = {"access_token":access_token}

root_1 = 'https://api.genius.com/'
endpoint_1 = 'search?q=Bob%20Dylan'
endpoint_1  # end point link
# Out:
# 'search?q=Bob%20Dylan'

# %%
link = root_1 + endpoint_1
df = requests.get(link, params = p_dict)
df_text_1 = json.loads(df.text)
df_text_1['response']['hits']
# Out:
# [{'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 127,
#    'api_path': '/songs/5393247',
#    'full_title': 'Murder Most Foul by\xa0Bob\xa0Dylan',
#    'header_image_thumbnail_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.1000x1000x1.jpg',
#    'id': 5393247,
#    'lyrics_owner_id': 3360167,
#    'lyrics_state': 'complete',
#    'path': '/Bob-dylan-murder-most-foul-lyrics',
#    'pyongs_count': 35,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.300x300x1.jpg',
#    'song_art_image_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.1000x1000x1.jpg',
#    'stats': {'unreviewed_annotations': 48, 'hot': False, 'pageviews': 440011},
#    'title': 'Murder Most Foul',
#    'title_with_featured': 'Murder Most Foul',
#    'url': 'https://genius.com/Bob-dylan-murder-most-foul-lyrics',
#    'primary_artist': {'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/facc753d420efc53bbe1e0b63a72d70b.960x719x1.jpg',
#     'id': 181,
#     'image_url': 'https://images.genius.com/22306423b6ad8777d1ed5b33ad8b0d0b.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 12,
#    'api_path': '/songs/79424',
#    'full_title': "Blowin' in the Wind by\xa0Bob\xa0Dylan",
#    'header_image_thumbnail_url': 'https://images.genius.com/afd28edb1b2d6d5d556a7b01b108c716.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/afd28edb1b2d6d5d556a7b01b108c716.500x500x1.jpg',
#    'id': 79424,
#    'lyrics_owner_id': 73267,
#    'lyrics_state': 'complete',
#    'path': '/Bob-dylan-blowin-in-the-wind-lyrics',
#    'pyongs_count': 43,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/afd28edb1b2d6d5d556a7b01b108c716.300x300x1.jpg',
#    'song_art_image_url': 'https://images.genius.com/afd28edb1b2d6d5d556a7b01b108c716.500x500x1.jpg',
#    'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 385079},
#    'title': 'Blowin’ in the Wind',
#    'title_with_featured': "Blowin' in the Wind",
#    'url': 'https://genius.com/Bob-dylan-blowin-in-the-wind-lyrics',
#    'primary_artist': {'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/facc753d420efc53bbe1e0b63a72d70b.960x719x1.jpg',
#     'id': 181,
#     'image_url': 'https://images.genius.com/22306423b6ad8777d1ed5b33ad8b0d0b.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 15,
#    'api_path': '/songs/98664',
#    'full_title': 'All Along the Watchtower by\xa0Bob\xa0Dylan',
#    'header_image_thumbnail_url': 'https://images.genius.com/f727dfc7b28942c59cd6695d9a2dcf2c.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/f727dfc7b28942c59cd6695d9a2dcf2c.1000x1000x1.jpg',
#    'id': 98664,
#    'lyrics_owner_id': 779,
#    'lyrics_state': 'complete',
#    'path': '/Bob-dylan-all-along-the-watchtower-lyrics',
#    'pyongs_count': 40,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.300x300x1.jpg',
#    'song_art_image_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.320x320x1.jpg',
#    'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 290149},
#    'title': 'All Along the Watchtower',
#    'title_with_featured': 'All Along the Watchtower',
#    'url': 'https://genius.com/Bob-dylan-all-along-the-watchtower-lyrics',
#    'primary_artist': {'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/facc753d420efc53bbe1e0b63a72d70b.960x719x1.jpg',
#     'id': 181,
#     'image_url': 'https://images.genius.com/22306423b6ad8777d1ed5b33ad8b0d0b.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 17,
#    'api_path': '/songs/62605',
#    'full_title': "The Times They Are A-Changin' by\xa0Bob\xa0Dylan",
#    'header_image_thumbnail_url': 'https://images.genius.com/bb0d6623d70dfad2803c18ed2f1c875e.300x315x1.jpg',
#    'header_image_url': 'https://images.genius.com/bb0d6623d70dfad2803c18ed2f1c875e.571x600x1.jpg',
#    'id': 62605,
#    'lyrics_owner_id': 49202,
#    'lyrics_state': 'complete',
#    'path': '/Bob-dylan-the-times-they-are-a-changin-lyrics',
#    'pyongs_count': 36,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/bb0d6623d70dfad2803c18ed2f1c875e.300x315x1.jpg',
#    'song_art_image_url': 'https://images.genius.com/bb0d6623d70dfad2803c18ed2f1c875e.571x600x1.jpg',
#    'stats': {'unreviewed_annotations': 2,
#     'concurrents': 2,
#     'hot': False,
#     'pageviews': 307129},
#    'title': 'The Times They Are A-Changin’',
#    'title_with_featured': "The Times They Are A-Changin'",
#    'url': 'https://genius.com/Bob-dylan-the-times-they-are-a-changin-lyrics',
#    'primary_artist': {'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/facc753d420efc53bbe1e0b63a72d70b.960x719x1.jpg',
#     'id': 181,
#     'image_url': 'https://images.genius.com/22306423b6ad8777d1ed5b33ad8b0d0b.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 19,
#    'api_path': '/songs/54784',
#    'full_title': 'Like a Rolling Stone by\xa0Bob\xa0Dylan',
#    'header_image_thumbnail_url': 'https://images.genius.com/5de9704b9bd8773ddbcb1de962f62386.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/5de9704b9bd8773ddbcb1de962f62386.1000x1000x1.jpg',
#    'id': 54784,
#    'lyrics_owner_id': 7,
#    'lyrics_state': 'complete',
#    'path': '/Bob-dylan-like-a-rolling-stone-lyrics',
#    'pyongs_count': 58,
#    'song_art_image_thumbnail_url': 'https://images.rapgenius.com/ea5vrna5a2wk2egyrrolaf40c.300x299x1.jpg',
#    'song_art_image_url': 'https://images.rapgenius.com/ea5vrna5a2wk2egyrrolaf40c.320x319x1.jpg',
#    'stats': {'unreviewed_annotations': 3, 'hot': False, 'pageviews': 275987},
#    'title': 'Like a Rolling Stone',
#    'title_with_featured': 'Like a Rolling Stone',
#    'url': 'https://genius.com/Bob-dylan-like-a-rolling-stone-lyrics',
#    'primary_artist': {'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/facc753d420efc53bbe1e0b63a72d70b.960x719x1.jpg',
#     'id': 181,
#     'image_url': 'https://images.genius.com/22306423b6ad8777d1ed5b33ad8b0d0b.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 8,
#    'api_path': '/songs/79749',
#    'full_title': 'Make You Feel My Love by\xa0Bob\xa0Dylan',
#    'header_image_thumbnail_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.1000x1000x1.jpg',
#    'id': 79749,
#    'lyrics_owner_id': 5307,
#    'lyrics_state': 'complete',
#    'path': '/Bob-dylan-make-you-feel-my-love-lyrics',
#    'pyongs_count': 10,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.300x300x1.jpg',
#    'song_art_image_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.1000x1000x1.jpg',
#    'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 260796},
#    'title': 'Make You Feel My Love',
#    'title_with_featured': 'Make You Feel My Love',
#    'url': 'https://genius.com/Bob-dylan-make-you-feel-my-love-lyrics',
#    'primary_artist': {'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/facc753d420efc53bbe1e0b63a72d70b.960x719x1.jpg',
#     'id': 181,
#     'image_url': 'https://images.genius.com/22306423b6ad8777d1ed5b33ad8b0d0b.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 14,
#    'api_path': '/songs/87402',
#    'full_title': 'Hurricane by\xa0Bob\xa0Dylan',
#    'header_image_thumbnail_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.300x299x1.jpg',
#    'header_image_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.567x566x1.jpg',
#    'id': 87402,
#    'lyrics_owner_id': 132320,
#    'lyrics_state': 'complete',
#    'path': '/Bob-dylan-hurricane-lyrics',
#    'pyongs_count': 21,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.300x299x1.jpg',
#    'song_art_image_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.567x566x1.jpg',
#    'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 221415},
#    'title': 'Hurricane',
#    'title_with_featured': 'Hurricane',
#    'url': 'https://genius.com/Bob-dylan-hurricane-lyrics',
#    'primary_artist': {'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/facc753d420efc53bbe1e0b63a72d70b.960x719x1.jpg',
#     'id': 181,
#     'image_url': 'https://images.genius.com/22306423b6ad8777d1ed5b33ad8b0d0b.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 9,
#    'api_path': '/songs/84846',
#    'full_title': "Don't Think Twice, It's All Right by\xa0Bob\xa0Dylan",
#    'header_image_thumbnail_url': 'https://images.genius.com/afd28edb1b2d6d5d556a7b01b108c716.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/afd28edb1b2d6d5d556a7b01b108c716.500x500x1.jpg',
#    'id': 84846,
#    'lyrics_owner_id': 125524,
#    'lyrics_state': 'complete',
#    'path': '/Bob-dylan-dont-think-twice-its-all-right-lyrics',
#    'pyongs_count': 21,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/afd28edb1b2d6d5d556a7b01b108c716.300x300x1.jpg',
#    'song_art_image_url': 'https://images.genius.com/afd28edb1b2d6d5d556a7b01b108c716.500x500x1.jpg',
#    'stats': {'unreviewed_annotations': 5,
#     'concurrents': 2,
#     'hot': False,
#     'pageviews': 199222},
#    'title': 'Don’t Think Twice, It’s All Right',
#    'title_with_featured': "Don't Think Twice, It's All Right",
#    'url': 'https://genius.com/Bob-dylan-dont-think-twice-its-all-right-lyrics',
#    'primary_artist': {'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/facc753d420efc53bbe1e0b63a72d70b.960x719x1.jpg',
#     'id': 181,
#     'image_url': 'https://images.genius.com/22306423b6ad8777d1ed5b33ad8b0d0b.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 18,
#    'api_path': '/songs/75446',
#    'full_title': 'Mr. Tambourine Man by\xa0Bob\xa0Dylan',
#    'header_image_thumbnail_url': 'https://images.genius.com/2fb972dceb4a8e726359e0335bcff19c.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/2fb972dceb4a8e726359e0335bcff19c.1000x1000x1.jpg',
#    'id': 75446,
#    'lyrics_owner_id': 74226,
#    'lyrics_state': 'complete',
#    'path': '/Bob-dylan-mr-tambourine-man-lyrics',
#    'pyongs_count': 19,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/2fb972dceb4a8e726359e0335bcff19c.300x300x1.jpg',
#    'song_art_image_url': 'https://images.genius.com/2fb972dceb4a8e726359e0335bcff19c.1000x1000x1.jpg',
#    'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 182021},
#    'title': 'Mr. Tambourine Man',
#    'title_with_featured': 'Mr. Tambourine Man',
#    'url': 'https://genius.com/Bob-dylan-mr-tambourine-man-lyrics',
#    'primary_artist': {'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/facc753d420efc53bbe1e0b63a72d70b.960x719x1.jpg',
#     'id': 181,
#     'image_url': 'https://images.genius.com/22306423b6ad8777d1ed5b33ad8b0d0b.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 19,
#    'api_path': '/songs/224',
#    'full_title': 'Subterranean Homesick Blues by\xa0Bob\xa0Dylan',
#    'header_image_thumbnail_url': 'https://images.genius.com/2fb972dceb4a8e726359e0335bcff19c.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/2fb972dceb4a8e726359e0335bcff19c.1000x1000x1.jpg',
#    'id': 224,
#    'lyrics_owner_id': 4,
#    'lyrics_state': 'complete',
#    'path': '/Bob-dylan-subterranean-homesick-blues-lyrics',
#    'pyongs_count': 33,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/2fb972dceb4a8e726359e0335bcff19c.300x300x1.jpg',
#    'song_art_image_url': 'https://images.genius.com/2fb972dceb4a8e726359e0335bcff19c.1000x1000x1.jpg',
#    'stats': {'unreviewed_annotations': 2, 'hot': False, 'pageviews': 129905},
#    'title': 'Subterranean Homesick Blues',
#    'title_with_featured': 'Subterranean Homesick Blues',
#    'url': 'https://genius.com/Bob-dylan-subterranean-homesick-blues-lyrics',
#    'primary_artist': {'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/facc753d420efc53bbe1e0b63a72d70b.960x719x1.jpg',
#     'id': 181,
#     'image_url': 'https://images.genius.com/22306423b6ad8777d1ed5b33ad8b0d0b.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}}}]

# %%
p_dict = {"access_token":access_token}

root_2 = 'https://api.genius.com/'
endpoint_2 = 'artists/181'
#format_1 = '.json'
link = root_2 + endpoint_2
df2 =requests.get(link, params = p_dict)
df_text_2 = json.loads(df2.text)
df_text_2
# Out:
# {'meta': {'status': 200},
#  'response': {'artist': {'alternate_names': ['Boo Wilbury',
#     'Lucky Wilbury',
#     'Robert Zimmerman',
#     'Robert A. Zimmerman',
#     'Robert Dylan',
#     'Robert Allen Zimmerman'],
#    'api_path': '/artists/181',
#    'description': {'dom': {'tag': 'root',
#      'children': [{'tag': 'p',
#        'children': ['Bob Dylan (born Robert Zimmerman May 24, 1941), is an American singer-songwriter, writer, and artist who has influenced popular music and culture for more than five decades. Dylan has especially played a critical role in the American folk music revival.']},
#       '',
#       {'tag': 'p',
#        'children': ['Dylan’s songs are built from myriad political, social, philosophical and literary influences. Many of his anti-war and civil-rights-influenced songs set social unrest, as journalists widely named him the “spokesman for his generation” in the 1960s.']},
#       '',
#       {'tag': 'p',
#        'children': ['The musician has a signature change in voice and style in many different albums of his throughout the decades. He has notably explored and experimented with the genres of folk, rap, blues, and rock.']},
#       '',
#       {'tag': 'p',
#        'children': ['Bob Dylan has sold more than 100 million records, making him one of the best-selling artists of all time. He has also played over 2,000 live shows, and is currently on a “Never Ending Tour” that is still going on since 1988. In 2016, Dylan became the first songwriter to be awarded the prestigious ',
#         {'tag': 'a',
#          'attributes': {'href': 'http://www.nobelprize.org/nobel_prizes/literature/laureates/2016/index.html',
#           'rel': 'noopener nofollow'},
#          'children': ['Nobel Prize in Literature']},
#         '.']}]}},
#    'facebook_name': 'bobdylan\u200e',
#    'followers_count': 494,
#    'header_image_url': 'https://images.genius.com/facc753d420efc53bbe1e0b63a72d70b.960x719x1.jpg',
#    'id': 181,
#    'image_url': 'https://images.genius.com/22306423b6ad8777d1ed5b33ad8b0d0b.1000x1000x1.jpg',
#    'instagram_name': '',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Bob Dylan',
#    'translation_artist': False,
#    'twitter_name': 'bobdylan',
#    'url': 'https://genius.com/artists/Bob-dylan',
#    'current_user_metadata': {'permissions': ['view_activity_stream'],
#     'excluded_permissions': ['edit',
#      'edit_images',
#      'edit_names',
#      'edit_anything',
#      'merge',
#      'sort_artist_songs',
#      'follow',
#      'view_contribution_opportunities',
#      'edit_translation_artist',
#      'see_short_id'],
#     'interactions': {'following': False}},
#    'description_annotation': {'_type': 'referent',
#     'annotator_id': 4,
#     'annotator_login': 'murkle',
#     'api_path': '/referents/6925802',
#     'classification': 'accepted',
#     'fragment': 'Bob Dylan',
#     'id': 6925802,
#     'is_description': True,
#     'path': '/6925802/Bob-dylan/Bob-dylan',
#     'range': {'content': 'Bob Dylan'},
#     'song_id': None,
#     'url': 'https://genius.com/6925802/Bob-dylan/Bob-dylan',
#     'verified_annotator_ids': [],
#     'annotatable': {'api_path': '/artists/181',
#      'context': None,
#      'id': 181,
#      'image_url': 'https://images.genius.com/22306423b6ad8777d1ed5b33ad8b0d0b.1000x1000x1.jpg',
#      'link_title': 'Bob Dylan',
#      'title': 'Bob Dylan',
#      'type': 'Artist',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'annotations': [{'api_path': '/annotations/6925802',
#       'body': {'dom': {'tag': 'root',
#         'children': [{'tag': 'p',
#           'children': ['Bob Dylan (born Robert Zimmerman May 24, 1941), is an American singer-songwriter, writer, and artist who has influenced popular music and culture for more than five decades. Dylan has especially played a critical role in the American folk music revival.']},
#          '',
#          {'tag': 'p',
#           'children': ['Dylan’s songs are built from myriad political, social, philosophical and literary influences. Many of his anti-war and civil-rights-influenced songs set social unrest, as journalists widely named him the “spokesman for his generation” in the 1960s.']},
#          '',
#          {'tag': 'p',
#           'children': ['The musician has a signature change in voice and style in many different albums of his throughout the decades. He has notably explored and experimented with the genres of folk, rap, blues, and rock.']},
#          '',
#          {'tag': 'p',
#           'children': ['Bob Dylan has sold more than 100 million records, making him one of the best-selling artists of all time. He has also played over 2,000 live shows, and is currently on a “Never Ending Tour” that is still going on since 1988. In 2016, Dylan became the first songwriter to be awarded the prestigious ',
#            {'tag': 'a',
#             'attributes': {'href': 'http://www.nobelprize.org/nobel_prizes/literature/laureates/2016/index.html',
#              'rel': 'noopener nofollow'},
#             'children': ['Nobel Prize in Literature']},
#            '.']}]}},
#       'comment_count': 1,
#       'community': True,
#       'custom_preview': None,
#       'has_voters': True,
#       'id': 6925802,
#       'pinned': False,
#       'share_url': 'https://genius.com/6925802',
#       'source': None,
#       'state': 'accepted',
#       'url': 'https://genius.com/6925802/Bob-dylan/Bob-dylan',
#       'verified': False,
#       'votes_total': 65,
#       'current_user_metadata': {'permissions': ['create_comment'],
#        'excluded_permissions': ['vote',
#         'edit',
#         'cosign',
#         'uncosign',
#         'destroy',
#         'accept',
#         'reject',
#         'see_unreviewed',
#         'clear_votes',
#         'propose_edit_to',
#         'pin_to_profile',
#         'unpin_from_profile',
#         'update_source',
#         'edit_custom_preview'],
#        'interactions': {'cosign': False, 'pyong': False, 'vote': None},
#        'iq_by_action': {}},
#       'authors': [{'attribution': 0.8035714285714286,
#         'pinned_role': None,
#         'user': {'api_path': '/users/367095',
#          'avatar': {'tiny': {'url': 'https://images.rapgenius.com/avatars/tiny/518ade89a858fffce450ae7989332a0a',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://images.rapgenius.com/avatars/thumb/518ade89a858fffce450ae7989332a0a',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://images.rapgenius.com/avatars/small/518ade89a858fffce450ae7989332a0a',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://images.rapgenius.com/avatars/medium/518ade89a858fffce450ae7989332a0a',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://images.rapgenius.com/avatars/medium/518ade89a858fffce450ae7989332a0a',
#          'human_readable_role_for_display': 'Contributor',
#          'id': 367095,
#          'iq': 4487,
#          'login': 'verifiedaccount',
#          'name': 'verifiedaccount',
#          'role_for_display': 'contributor',
#          'url': 'https://genius.com/verifiedaccount',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.05952380952380953,
#         'pinned_role': None,
#         'user': {'api_path': '/users/1713313',
#          'avatar': {'tiny': {'url': 'https://images.rapgenius.com/avatars/tiny/d9b5c88b88763dfa1e7182f637a7715e',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://images.rapgenius.com/avatars/thumb/d9b5c88b88763dfa1e7182f637a7715e',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://images.rapgenius.com/avatars/small/d9b5c88b88763dfa1e7182f637a7715e',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://images.rapgenius.com/avatars/medium/d9b5c88b88763dfa1e7182f637a7715e',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://images.rapgenius.com/avatars/medium/d9b5c88b88763dfa1e7182f637a7715e',
#          'human_readable_role_for_display': 'Editor',
#          'id': 1713313,
#          'iq': 42759,
#          'login': 'MatthewDurrant',
#          'name': 'MatthewDurrant',
#          'role_for_display': 'editor',
#          'url': 'https://genius.com/MatthewDurrant',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.05357142857142857,
#         'pinned_role': None,
#         'user': {'api_path': '/users/16',
#          'avatar': {'tiny': {'url': 'https://s3.amazonaws.com/rapgenius/avatars/tiny/Sf2Ln6jT56GIeteSc7gq.jpg',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://s3.amazonaws.com/rapgenius/avatars/thumb/Sf2Ln6jT56GIeteSc7gq.jpg',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://s3.amazonaws.com/rapgenius/avatars/small/Sf2Ln6jT56GIeteSc7gq.jpg',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://s3.amazonaws.com/rapgenius/avatars/medium/Sf2Ln6jT56GIeteSc7gq.jpg',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://s3.amazonaws.com/rapgenius/avatars/medium/Sf2Ln6jT56GIeteSc7gq.jpg',
#          'human_readable_role_for_display': 'Editor',
#          'id': 16,
#          'iq': 522191,
#          'login': 'SameOldShawn',
#          'name': 'SameOldShawn',
#          'role_for_display': 'editor',
#          'url': 'https://genius.com/SameOldShawn',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.023809523809523808,
#         'pinned_role': None,
#         'user': {'api_path': '/users/1544762',
#          'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/d5df7ef5fe8aca8224870b270ff27188',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://images.genius.com/avatars/thumb/d5df7ef5fe8aca8224870b270ff27188',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://images.genius.com/avatars/small/d5df7ef5fe8aca8224870b270ff27188',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://images.genius.com/avatars/medium/d5df7ef5fe8aca8224870b270ff27188',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://images.genius.com/avatars/medium/d5df7ef5fe8aca8224870b270ff27188',
#          'human_readable_role_for_display': 'Editor',
#          'id': 1544762,
#          'iq': 46325,
#          'login': 'urtalseenioop',
#          'name': 'Max hiney 🌸',
#          'role_for_display': 'editor',
#          'url': 'https://genius.com/urtalseenioop',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.01785714285714286,
#         'pinned_role': None,
#         'user': {'api_path': '/users/2440225',
#          'avatar': {'tiny': {'url': 'https://images.rapgenius.com/avatars/tiny/3f8a363c7ab9c5a20ca7115f69a2a580',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://images.rapgenius.com/avatars/thumb/3f8a363c7ab9c5a20ca7115f69a2a580',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://images.rapgenius.com/avatars/small/3f8a363c7ab9c5a20ca7115f69a2a580',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://images.rapgenius.com/avatars/medium/3f8a363c7ab9c5a20ca7115f69a2a580',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://images.rapgenius.com/avatars/medium/3f8a363c7ab9c5a20ca7115f69a2a580',
#          'human_readable_role_for_display': 'Contributor',
#          'id': 2440225,
#          'iq': 8424,
#          'login': 'simulacreage',
#          'name': 'simulacreage',
#          'role_for_display': 'contributor',
#          'url': 'https://genius.com/simulacreage',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.01785714285714286,
#         'pinned_role': None,
#         'user': {'api_path': '/users/4',
#          'avatar': {'tiny': {'url': 'https://assets.genius.com/images/default_avatar_16.png?1601047781',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://assets.genius.com/images/default_avatar_32.png?1601047781',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://assets.genius.com/images/default_avatar_100.png?1601047781',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://assets.genius.com/images/default_avatar_300.png?1601047781',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://assets.genius.com/images/default_avatar_300.png?1601047781',
#          'human_readable_role_for_display': 'Contributor',
#          'id': 4,
#          'iq': 33226,
#          'login': 'murkle',
#          'name': 'Murklederderder',
#          'role_for_display': 'contributor',
#          'url': 'https://genius.com/murkle',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.011904761904761904,
#         'pinned_role': None,
#         'user': {'api_path': '/users/6931181',
#          'avatar': {'tiny': {'url': 'https://s3.amazonaws.com/filepicker-images-rapgenius/2x5w2zv4d9m',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://s3.amazonaws.com/filepicker-images-rapgenius/2x5w2zv4d9m',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://s3.amazonaws.com/filepicker-images-rapgenius/2x5w2zv4d9m',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://s3.amazonaws.com/filepicker-images-rapgenius/2x5w2zv4d9m',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://s3.amazonaws.com/filepicker-images-rapgenius/qlem5fzp9n',
#          'human_readable_role_for_display': 'Editor',
#          'id': 6931181,
#          'iq': 23009,
#          'login': 'indielens',
#          'name': 'indielens',
#          'role_for_display': 'editor',
#          'url': 'https://genius.com/indielens',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.005952380952380952,
#         'pinned_role': None,
#         'user': {'api_path': '/users/5077322',
#          'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/f6c51eeb13288750bd6dd58f854c5f12',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://images.genius.com/avatars/thumb/f6c51eeb13288750bd6dd58f854c5f12',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://images.genius.com/avatars/small/f6c51eeb13288750bd6dd58f854c5f12',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://images.genius.com/avatars/medium/f6c51eeb13288750bd6dd58f854c5f12',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://images.genius.com/d8c4727c568093ee9e0377761356d48b.1000x662x1.jpg',
#          'human_readable_role_for_display': 'Editor',
#          'id': 5077322,
#          'iq': 126425,
#          'login': 'sitzpinkler',
#          'name': 'Shashwat Bansal',
#          'role_for_display': 'editor',
#          'url': 'https://genius.com/sitzpinkler',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.005952380952380952,
#         'pinned_role': None,
#         'user': {'api_path': '/users/9706384',
#          'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/227cc068bfd8bdbd9ac9b59998ba885f',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://images.genius.com/avatars/thumb/227cc068bfd8bdbd9ac9b59998ba885f',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://images.genius.com/avatars/small/227cc068bfd8bdbd9ac9b59998ba885f',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://images.genius.com/avatars/medium/227cc068bfd8bdbd9ac9b59998ba885f',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://s3.amazonaws.com/filepicker-images-rapgenius/117g611sqf2',
#          'human_readable_role_for_display': None,
#          'id': 9706384,
#          'iq': 299,
#          'login': 'suqqakacktus',
#          'name': 'suqqakacktus',
#          'role_for_display': None,
#          'url': 'https://genius.com/suqqakacktus',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}}],
#       'cosigned_by': [],
#       'rejection_comment': None,
#       'verified_by': None}]},
#    'user': None}}}

# %%
df_text_1['response']['hits'][0]['result']['primary_artist']['id']    # artist ID
# Out:
# 181

# %%
endpoint_2  # end point link
# Out:
# 'artists/181'

# %% [markdown]
# ## Problem 4
# Add `/songs` to the end of the the endpoint path you found in problem 3 and use this path to request the 20 most popular Bob Dylan songs. Organize these data in a `pandas` data frame. [4 points]

# %%
p4_link = link + '/songs'
p4_link 
#df5 = requests.get(p4_link, params = p_dict)
#df5_1 = json.loads(df5.text)
# Out:
# 'https://api.genius.com/artists/181/songs'

# %%
extra = '?sort=title'
p4_link_extra = p4_link + extra

# %%
df6 = requests.get(p4_link_extra, params = p_dict)
df6_1 = json.loads(df6.text)

# %%
pd.json_normalize(df6_1, record_path = ["response", "songs"])
# Out:
#     annotation_count        api_path  \
# 0                  1   /songs/200681
# 1                  1   /songs/200682
# 2                  1  /songs/1686914
# 3                 14   /songs/105774
# 4                  1   /songs/994912
# 5                  1  /songs/1493543
# 6                  1  /songs/1994655
# 7                  1  /songs/1390070
# 8                  0  /songs/5754536
# 9                  1  /songs/2234570
# 10                 3   /songs/118651
# 11                 4   /songs/105773
# 12                 1   /songs/941697
# 13                 0  /songs/4111895
# 14                 1  /songs/1534549
# 15                 2  /songs/4320704
# 16                 1   /songs/199634
# 17                31   /songs/105186
# 18                 1  /songs/3349860
# 19                 1  /songs/1709800
#
#                                            full_title  \
# 0                             10,000 Men by Bob Dylan
# 1                                  2 X 2 by Bob Dylan
# 2                            32-20 Blues by Bob Dylan
# 3                        4th Time Around by Bob Dylan
# 4                  4th Time Around by Robyn Hitchcock
# 5                 7 Deadly Sins by Traveling Wilburys
# 6                 900 Miles from My Home by Bob Dylan
# 7              Abandoned Love by ​The Everly Brothers
# 8                     Abandoned Love by Gillian Welch
# 9   Abandoned Love by Paul Rodgers (Ft. Nils Lofgren)
# 10  Abandoned Love by Bob Dylan (Ft. George Harrison)
# 11                Absolutely Sweet Marie by Bob Dylan
# 12          Absolutely Sweet Marie by George Harrison
# 13  Acido Seminterrato (Subterranean Homesick Blue...
# 14                                  Acne by Bob Dylan
# 15        Advice to A Young Writer by John Paul Davis
# 16                      A Fool Such as I by Bob Dylan
# 17            A Hard Rain's a-Gonna Fall by Bob Dylan
# 18      A Hard Rain's A Gonna Fall by Heather Maloney
# 19          A Hard Rain's A-Gonna Fall by Bryan Ferry
#
#                            header_image_thumbnail_url  \
# 0   https://images.genius.com/9a0da499b7383ddf2327...
# 1   https://images.genius.com/9a0da499b7383ddf2327...
# 2   https://s3.amazonaws.com/rapgenius/1375877710_...
# 3   https://images.genius.com/f96e173addad27a13065...
# 4   https://images.genius.com/4476c7b6ab3bd711b40f...
# 5   https://images.genius.com/eda586eb0d4993017d17...
# 6   https://images.genius.com/22306423b6ad8777d1ed...
# 7   https://images.genius.com/1f4c52f1b87fd252455f...
# 8   https://images.genius.com/9c5f4e16c1a98d20850b...
# 9   https://images.genius.com/5467e90c6f628d46c2c9...
# 10  https://images.genius.com/3473ef0e3a751805b4da...
# 11  https://images.genius.com/f96e173addad27a13065...
# 12  https://images.genius.com/a107d4ceec3046900f54...
# 13  https://images.genius.com/491379012f4984d452b8...
# 14  https://images.genius.com/22306423b6ad8777d1ed...
# 15  https://assets.genius.com/images/default_cover...
# 16  https://s3.amazonaws.com/rapgenius/Bob-Dylan-D...
# 17  https://images.genius.com/afd28edb1b2d6d5d556a...
# 18  https://images.genius.com/26bbcb4f2605c5ad94c5...
# 19  https://images.genius.com/a216aa5130d6608a1630...
#
#                                      header_image_url       id  \
# 0   https://images.genius.com/9a0da499b7383ddf2327...   200681
# 1   https://images.genius.com/9a0da499b7383ddf2327...   200682
# 2   https://s3.amazonaws.com/rapgenius/1375877710_...  1686914
# 3   https://images.genius.com/f96e173addad27a13065...   105774
# 4   https://images.genius.com/4476c7b6ab3bd711b40f...   994912
# 5   https://images.genius.com/eda586eb0d4993017d17...  1493543
# 6   https://images.genius.com/22306423b6ad8777d1ed...  1994655
# 7   https://images.genius.com/1f4c52f1b87fd252455f...  1390070
# 8   https://images.genius.com/9c5f4e16c1a98d20850b...  5754536
# 9   https://images.genius.com/5467e90c6f628d46c2c9...  2234570
# 10  https://images.genius.com/3473ef0e3a751805b4da...   118651
# 11  https://images.genius.com/f96e173addad27a13065...   105773
# 12  https://images.genius.com/a107d4ceec3046900f54...   941697
# 13  https://images.genius.com/491379012f4984d452b8...  4111895
# 14  https://images.genius.com/22306423b6ad8777d1ed...  1534549
# 15  https://assets.genius.com/images/default_cover...  4320704
# 16  https://s3.amazonaws.com/rapgenius/Bob-Dylan-D...   199634
# 17  https://images.genius.com/afd28edb1b2d6d5d556a...   105186
# 18  https://images.genius.com/26bbcb4f2605c5ad94c5...  3349860
# 19  https://images.genius.com/a216aa5130d6608a1630...  1709800
#
#     lyrics_owner_id lyrics_state  \
# 0            225680     complete
# 1            225680     complete
# 2           1549345     complete
# 3                16     complete
# 4           1549345     complete
# 5           1549345     complete
# 6             30682     complete
# 7           1549345     complete
# 8           1168310     complete
# 9           1549345     complete
# 10           188147     complete
# 11               16     complete
# 12          1549345     complete
# 13          6845368     complete
# 14          1549345     complete
# 15          3528500     complete
# 16           250962     complete
# 17               16     complete
# 18          4868239     complete
# 19          1549345     complete
#
#                                                  path  pyongs_count  ...  \
# 0                         /Bob-dylan-10000-men-lyrics           NaN  ...
# 1                             /Bob-dylan-2-x-2-lyrics           NaN  ...
# 2                       /Bob-dylan-32-20-blues-lyrics           NaN  ...
# 3                   /Bob-dylan-4th-time-around-lyrics           3.0  ...
# 4             /Robyn-hitchcock-4th-time-around-lyrics           NaN  ...
# 5            /Traveling-wilburys-7-deadly-sins-lyrics           NaN  ...
# 6            /Bob-dylan-900-miles-from-my-home-lyrics           NaN  ...
# 7          /The-everly-brothers-abandoned-love-lyrics           NaN  ...
# 8                /Gillian-welch-abandoned-love-lyrics           NaN  ...
# 9                 /Paul-rodgers-abandoned-love-lyrics           NaN  ...
# 10                   /Bob-dylan-abandoned-love-lyrics           4.0  ...
# 11           /Bob-dylan-absolutely-sweet-marie-lyrics           NaN  ...
# 12     /George-harrison-absolutely-sweet-marie-lyrics           NaN  ...
# 13  /Francesco-de-gregori-acido-seminterrato-subte...           NaN  ...
# 14                             /Bob-dylan-acne-lyrics           NaN  ...
# 15  /John-paul-davis-advice-to-a-young-writer-anno...           NaN  ...
# 16                 /Bob-dylan-a-fool-such-as-i-lyrics           NaN  ...
# 17        /Bob-dylan-a-hard-rains-a-gonna-fall-lyrics          20.0  ...
# 18  /Heather-maloney-a-hard-rains-a-gonna-fall-lyrics           NaN  ...
# 19      /Bryan-ferry-a-hard-rains-a-gonna-fall-lyrics           NaN  ...
#
#    primary_artist.api_path                    primary_artist.header_image_url  \
# 0             /artists/181  https://images.genius.com/facc753d420efc53bbe1...
# 1             /artists/181  https://images.genius.com/facc753d420efc53bbe1...
# 2             /artists/181  https://images.genius.com/facc753d420efc53bbe1...
# 3             /artists/181  https://images.genius.com/facc753d420efc53bbe1...
# 4           /artists/90989  https://images.genius.com/75e0332313e5e1a4c076...
# 5           /artists/60612  https://images.genius.com/609e88d8b00dca0919f0...
# 6             /artists/181  https://images.genius.com/facc753d420efc53bbe1...
# 7           /artists/44139  https://images.genius.com/f1bea76bd837ee54f1a0...
# 8           /artists/43258  https://images.genius.com/d19d268fb8da9eed55d2...
# 9          /artists/356096  https://images.genius.com/7e6e28bff1b2d4802e47...
# 10            /artists/181  https://images.genius.com/facc753d420efc53bbe1...
# 11            /artists/181  https://images.genius.com/facc753d420efc53bbe1...
# 12          /artists/33327  https://images.genius.com/7df9df41079ba76c44b2...
# 13         /artists/344502  https://images.genius.com/64b153d8e0e91fa40bcd...
# 14            /artists/181  https://images.genius.com/facc753d420efc53bbe1...
# 15        /artists/1722068  https://assets.genius.com/images/default_avata...
# 16            /artists/181  https://images.genius.com/facc753d420efc53bbe1...
# 17            /artists/181  https://images.genius.com/facc753d420efc53bbe1...
# 18        /artists/1274445  https://images.genius.com/c9930341c0379640f71b...
# 19         /artists/204913  https://images.genius.com/3251922228afe828c6b0...
#
#    primary_artist.id                           primary_artist.image_url  \
# 0                181  https://images.genius.com/22306423b6ad8777d1ed...
# 1                181  https://images.genius.com/22306423b6ad8777d1ed...
# 2                181  https://images.genius.com/22306423b6ad8777d1ed...
# 3                181  https://images.genius.com/22306423b6ad8777d1ed...
# 4              90989  https://images.genius.com/75e0332313e5e1a4c076...
# 5              60612  https://images.genius.com/c859d02ba3a25da3b1f9...
# 6                181  https://images.genius.com/22306423b6ad8777d1ed...
# 7              44139  https://images.genius.com/64945eb6f723abe47bf2...
# 8              43258  https://images.genius.com/237d93df46719e977db2...
# 9             356096  https://images.genius.com/7e6e28bff1b2d4802e47...
# 10               181  https://images.genius.com/22306423b6ad8777d1ed...
# 11               181  https://images.genius.com/22306423b6ad8777d1ed...
# 12             33327  https://images.genius.com/deb15cee0a703ee60b76...
# 13            344502  https://images.genius.com/63f147c58e8024d31a76...
# 14               181  https://images.genius.com/22306423b6ad8777d1ed...
# 15           1722068  https://assets.genius.com/images/default_avata...
# 16               181  https://images.genius.com/22306423b6ad8777d1ed...
# 17               181  https://images.genius.com/22306423b6ad8777d1ed...
# 18           1274445  https://images.genius.com/c9930341c0379640f71b...
# 19            204913  https://images.genius.com/fc5cfc84743582dd600f...
#
#    primary_artist.is_meme_verified  primary_artist.is_verified  \
# 0                            False                       False
# 1                            False                       False
# 2                            False                       False
# 3                            False                       False
# 4                            False                       False
# 5                            False                       False
# 6                            False                       False
# 7                            False                       False
# 8                            False                       False
# 9                            False                       False
# 10                           False                       False
# 11                           False                       False
# 12                           False                       False
# 13                           False                       False
# 14                           False                       False
# 15                           False                       False
# 16                           False                       False
# 17                           False                       False
# 18                           False                       False
# 19                           False                       False
#
#      primary_artist.name                               primary_artist.url  \
# 0              Bob Dylan             https://genius.com/artists/Bob-dylan
# 1              Bob Dylan             https://genius.com/artists/Bob-dylan
# 2              Bob Dylan             https://genius.com/artists/Bob-dylan
# 3              Bob Dylan             https://genius.com/artists/Bob-dylan
# 4        Robyn Hitchcock       https://genius.com/artists/Robyn-hitchcock
# 5     Traveling Wilburys    https://genius.com/artists/Traveling-wilburys
# 6              Bob Dylan             https://genius.com/artists/Bob-dylan
# 7   ​The Everly Brothers   https://genius.com/artists/The-everly-brothers
# 8          Gillian Welch         https://genius.com/artists/Gillian-welch
# 9           Paul Rodgers          https://genius.com/artists/Paul-rodgers
# 10             Bob Dylan             https://genius.com/artists/Bob-dylan
# 11             Bob Dylan             https://genius.com/artists/Bob-dylan
# 12       George Harrison       https://genius.com/artists/George-harrison
# 13  Francesco De Gregori  https://genius.com/artists/Francesco-de-gregori
# 14             Bob Dylan             https://genius.com/artists/Bob-dylan
# 15       John Paul Davis       https://genius.com/artists/John-paul-davis
# 16             Bob Dylan             https://genius.com/artists/Bob-dylan
# 17             Bob Dylan             https://genius.com/artists/Bob-dylan
# 18       Heather Maloney       https://genius.com/artists/Heather-maloney
# 19           Bryan Ferry           https://genius.com/artists/Bryan-ferry
#
#    stats.pageviews  stats.concurrents
# 0              NaN                NaN
# 1              NaN                NaN
# 2              NaN                NaN
# 3          21573.0                NaN
# 4              NaN                NaN
# 5              NaN                NaN
# 6              NaN                NaN
# 7              NaN                NaN
# 8              NaN                NaN
# 9              NaN                NaN
# 10          5156.0                NaN
# 11         10391.0                NaN
# 12             NaN                NaN
# 13             NaN                NaN
# 14             NaN                NaN
# 15             NaN                NaN
# 16             NaN                NaN
# 17        131142.0                3.0
# 18             NaN                NaN
# 19             NaN                NaN
#
# [20 rows x 27 columns]

# %% [markdown]
# ## Problem 5
# Install and import the `lyricsgenius` library in Python, which is a wrapper around `requests` that works specifically with the Genius API. . Follow the guide on the GitHub repository for this library (https://github.com/johnwmillr/LyricsGenius) for instructions on using the library. Use the `lyricsgenius` library to download and display the lyrics to "Tangled Up in Blue" by Bob Dylan. [4 points]

# %%
import lyricsgenius
genius = lyricsgenius.Genius(access_token)
song = genius.search_song("Tangled Up in Blue", 'Bob Dylan')
print(song.lyrics)
# Out:
# Searching for "Tangled Up in Blue" by Bob Dylan...
# Done.
# [Verse 1]
# Early one morning the sun was shining
# I was laying in bed
# Wondering if she'd changed at all
# If her hair was still red
# Her folks they said our lives together
# Sure was going to be rough
# They never did like Mama's homemade dress
# Papa's bankbook wasn't big enough
# And I was standing on the side of the road
# Rain falling on my shoes
# Heading out for the East Coast
# Lord knows I've paid some dues
# Getting through
# Tangled up in blue
#
# [Verse 2]
# She was married when we first met
# Soon to be divorced
# I helped her out of a jam, I guess
# But I used a little too much force
# We drove that car as far as we could
# Abandoned it out West
# Split up on a dark sad night
# Both agreeing it was best
# She turned around to look at me
# As I was walking away
# I heard her say over my shoulder
# "We'll meet again someday
# On the avenue"
# Tangled up in blue
#
# [Verse 3]
# I had a job in the great north woods
# Working as a cook for a spell
# But I never did like it all that much
# And one day the ax just fell
# So I drifted down to New Orleans
# Where I lucky was to be employed
# Working for a while on a fishing boat
# Right outside of Delacroix
# But all the while I was alone
# The past was close behind
# I seen a lot of women
# But she never escaped my mind
# And I just grew
# Tangled up in blue
#
# [Verse 4]
# She was working in a topless place
# And I stopped in for a beer
# I just kept looking at the side of her face
# In the spotlight, so clear
# And later on, when the crowd thinned out
# I was just about to do the same
# She was standing there, in back of my chair
# Said to me "Tell me, don't I know your name?"
# I muttered something underneath my breath
# She studied the lines on my face
# I must admit, I felt a little uneasy
# When she bent down to tie the laces
# Of my shoe
# Tangled up in blue
#
# [Verse 5]
# She lit a burner on the stove
# And offered me a pipe
# "I thought you'd never say hello" she said
# "You look like the silent type"
# Then she opened up a book of poems
# And handed it to me
# Written by an Italian poet
# From the thirteenth century
# And every one of them words rang true
# And glowed like burning coal
# Pouring off of every page
# Like it was written in my soul
# From me to you
# Tangled up in blue
#
# [Verse 6]
# I lived with them on Montague Street
# In a basement down the stairs
# There was music in the cafes at night
# And revolution in the air
# Then he started into dealing with slaves
# And something inside of him died
# She had to sell everything she owned
# And froze up inside
# And when it finally, the bottom fell out
# I became withdrawn
# The only thing I knew how to do
# Was to keep on keeping on
# Like a bird that flew
# Tangled up in blue
#
# [Verse 7]
# So now I'm going back again
# I got to get to her somehow
# All the people we used to know
# They're an illusion to me now
# Some are mathematicians
# Some are carpenter's wives
# Don't know how it all got started
# I don't know what they're doing with their lives
# But me, I'm still on the road
# A-heading for another joint
# We always did feel the same
# We just saw it from a different point
# Of view
# Tangled up in blue
